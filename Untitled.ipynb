# %%
dump = pd.read_json('dump.json')
dump['size'].hist()

# %%
print(dump['size'])

print(type(dump['size']))
# Out:
# 0        221956
# 1         11593
# 2         15863
# 3         78222
# 4         23550
#           ...
# 18841     14277
# 18842     13953
# 18843      7960
# 18844      7875
# 18845      6036
# Name: size, Length: 18846, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(dump['size'].index)
# Out:
# RangeIndex(start=0, stop=18846, step=1)

# %%
print(dump['size'].values)
# Out:
# [221956  11593  15863 ...   7960   7875   6036]

# %%
dump['size'].plot.hist()

# %%
import matplotlib.pyplot as plt

plt.hist(dump['size'].values, bins=[50000, 100000,200000, 300000, 400000,500000, 600000, 700000, 800000, 900000, 1000000, 5000000])
plt.grid()

# %%
dump['size'].describe()
# Out:
# count    1.884600e+04
# mean     5.790807e+04
# std      1.432821e+05
# min      3.206000e+03
# 25%      1.109225e+04
# 50%      2.372450e+04
# 75%      4.261600e+04
# max      5.235500e+06
# Name: size, dtype: float64

# %%
dump[dump['size'] > 50000].shape
# Out:
# (4185, 6)

# %%
dump.shape
# Out:
# (18846, 6)

# %%
main = dump[dump['size'] < 50000]
main['size'].hist(bins=20)

# %%
x = [2500*sub for sub in range(0, 22)]
plt.figure(figsize=(20, 8), dpi=80)
plt.hist(main['size'].values, bins=range(0, 50000+1, 2500), label='email')
plt.grid()
plt.legend()
plt.xticks(x, ['{:.1f}KB'.format(sub/1000) for sub in x])
plt.show()
